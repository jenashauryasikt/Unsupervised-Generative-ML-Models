# %% [markdown]
# # Pinwheel Dataset
#
# Pinwheel dataset subject to unsupervised generation by 4 models:
#
# 1. Denoising Score Matching (DSM)
# 2. Denoising Diffusion Probabilistic Model (DDPM)
# 3. Generative Adversarial Networks (GAN)
# 4. Energy Based Model (EBM)

# %%
## importing required libraries
from typing import Callable, Iterator, Sequence
import functools

import numpy as np
import scipy as sp
from scipy.stats import gaussian_kde
import matplotlib.pylab as plt

import jax.numpy as jnp
import jax.scipy as jsp
import jax
import flax.linen as nn
import optax
import haiku as hk
import chex
import tqdm

# %%
## importing auxillary python modules
from dataset_generators import *
from utils import *
from dsm import *
from ddpm import *
from gan import *
from ebm import *

# %% [markdown]
# ## 1. Dataset

# %%
X_pinwheel = generate_pinwheel(num=2000, rng=rng)
plt.plot(X_pinwheel[:, 0], X_pinwheel[:, 1], '.')

# %% [markdown]
# ## 2. Models

# %%
## global variables
prng_seq = hk.PRNGSequence(jax.random.PRNGKey(0))
noise = 2 * jax.random.normal(next(prng_seq), shape=(2000, 2))

# %% [markdown]
# ### 2.1 Denoising Score Matching (DSM)

# %%
dsm_model = DSM_MLP(features=[128, 128, 2])
step_size = 5e-3
num_steps = 2000

print(dsm_model.tabulate(jax.random.PRNGKey(0), np.zeros((1, 2))))
# Out:
#                                 DSM_MLP Summary
# ┏━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ path    ┃ module  ┃ inputs         ┃ outputs        ┃ params                 ┃
# ┡━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         │ DSM_MLP │ float32[1,2]   │ float32[1,2]   │                        │
# ├─────────┼─────────┼────────────────┼────────────────┼────────────────────────┤
# │ Dense_0 │ Dense   │ float32[1,2]   │ float32[1,128] │ bias: float32[128]     │
# │         │         │                │                │ kernel: float32[2,128] │
# │         │         │                │                │                        │
# │         │         │                │                │ 384 (1.5 KB)           │
# ├─────────┼─────────┼────────────────┼────────────────┼────────────────────────┤
# │ Dense_1 │ Dense   │ float32[1,128] │ float32[1,128] │ bias: float32[128]     │
# │         │         │                │                │ kernel:                │
# │         │         │                │                │ float32[128,128]       │
# │         │         │                │                │                        │
# │         │         │                │                │ 16,512 (66.0 KB)       │
# ├─────────┼─────────┼────────────────┼────────────────┼────────────────────────┤
# │ Dense_2 │ Dense   │ float32[1,128] │ float32[1,2]   │ bias: float32[2]       │
# │         │         │                │                │ kernel: float32[128,2] │
# │         │         │                │                │                        │
# │         │         │                │                │ 258 (1.0 KB)           │
# ├─────────┼─────────┼────────────────┼────────────────┼────────────────────────┤
# │         │         │                │          Total │ 17,154 (68.6 KB)       │
# └─────────┴─────────┴────────────────┴────────────────┴────────────────────────┘
#
#                        Total Parameters: 17,154 (68.6 KB)

# %%
## Training
params, train_losses, val_losses = DSM_train(X_pinwheel, lr=1e-3, clip_norm=0.1, 
                                     sigma=0.1, num_epochs=10000, batch_size=128, key=prng_seq)
# Out:
# 100%|██████████| 10000/10000 [00:27<00:00, 368.28it/s]

# %%
## Loss plots
DSM_training_plot(train_losses, val_losses, title='DSM: Pinwheel')

# %%
## Generation
dsm_samples = DSM_sampler(params, X_pinwheel, noise, step_size, num_steps, key=prng_seq)

# %%
## Energy density plot
'''
Lower energy signifies concentration of probability where datapoints should be.
'''
# Define the range for the grid
grid_x = np.linspace(np.min(X_pinwheel[:, 0])-1, np.max(X_pinwheel[:, 0])+1, 100)
grid_y = np.linspace(np.min(X_pinwheel[:, 1])-1, np.max(X_pinwheel[:, 1])+1, 100)

dsm_plot_energy_landscape(dsm_model, params, grid_x, grid_y)

# %%
## Gaussian KDE
plot_logpdf(X_pinwheel, dsm_samples, model_name='DSM', dataset_name='Pinwheel')
# Out:
# No. of clean samples = 2000
# Mean log(pdf) for DSM generated Pinwheel dataset = -1.0193473429879005

# %% [markdown]
# ### 2.2 Denoising Diffusion Probabilistic Model (DDPM)

# %%
# to be subtracted from 1.0 for ease of writing
sub_alpha_1 = 1e-4
sub_alpha_T = 0.02
T = 1000
ddpm_model = DDPM_MLP(features=[128, 128, 2], num_steps=T)

print(ddpm_model.tabulate(jax.random.PRNGKey(0), np.zeros((1,2)), 0))
# Out:
#                                 DDPM_MLP Summary
# ┏━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ path    ┃ module   ┃ inputs         ┃ outputs        ┃ params                ┃
# ┡━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━┩
# │         │ DDPM_MLP │ - float32[1,2] │ float32[1,2]   │                       │
# │         │          │ - 0            │                │                       │
# ├─────────┼──────────┼────────────────┼────────────────┼───────────────────────┤
# │ Embed_0 │ Embed    │ int32[1]       │ float32[1,128] │ embedding:            │
# │         │          │                │                │ float32[1000,128]     │
# │         │          │                │                │                       │
# │         │          │                │                │ 128,000 (512.0 KB)    │
# ├─────────┼──────────┼────────────────┼────────────────┼───────────────────────┤
# │ Dense_0 │ Dense    │ float32[1,130] │ float32[1,128] │ bias: float32[128]    │
# │         │          │                │                │ kernel:               │
# │         │          │                │                │ float32[130,128]      │
# │         │          │                │                │                       │
# │         │          │                │                │ 16,768 (67.1 KB)      │
# ├─────────┼──────────┼────────────────┼────────────────┼───────────────────────┤
# │ Dense_1 │ Dense    │ float32[1,128] │ float32[1,128] │ bias: float32[128]    │
# │         │          │                │                │ kernel:               │
# │         │          │                │                │ float32[128,128]      │
# │         │          │                │                │                       │
# │         │          │                │                │ 16,512 (66.0 KB)      │
# ├─────────┼──────────┼────────────────┼────────────────┼───────────────────────┤
# │ Dense_2 │ Dense    │ float32[1,128] │ float32[1,2]   │ bias: float32[2]      │
# │         │          │                │                │ kernel:               │
# │         │          │                │                │ float32[128,2]        │
# │         │          │                │                │                       │
# │         │          │                │                │ 258 (1.0 KB)          │
# ├─────────┼──────────┼────────────────┼────────────────┼───────────────────────┤
# │         │          │                │          Total │ 161,538 (646.2 KB)    │
# └─────────┴──────────┴────────────────┴────────────────┴───────────────────────┘
#
#                       Total Parameters: 161,538 (646.2 KB)

# %%
## Training
params, train_losses, val_losses, alphas, alphas_cumprod = DDPM_train(
    X_pinwheel, lr=1e-4, clip_norm=0.1, sub_alpha_1=sub_alpha_1,  
    sub_alpha_T=sub_alpha_T, T=T, num_epochs=500000, batch_size=128, key=prng_seq)
# Out:
# 100%|██████████| 500000/500000 [41:25<00:00, 201.19it/s]

# %%
## Loss plots
DDPM_training_plot(train_losses, val_losses, title='DDPM: Pinwheel')

# %%
## Generation
ddpm_samples = DDPM_sampler(params, X_pinwheel, noise, alphas, alphas_cumprod)

# %%
## Energy density plot
'''
Lower energy signifies concentration of probability where datapoints should be.
'''
# Define the range for the grid
grid_x = np.linspace(np.min(X_pinwheel[:, 0])-1, np.max(X_pinwheel[:, 0])+1, 100)
grid_y = np.linspace(np.min(X_pinwheel[:, 1])-1, np.max(X_pinwheel[:, 1])+1, 100)

ddpm_plot_energy_landscape(ddpm_model, params, grid_x, grid_y)

# %%
## Gaussian KDE
plot_logpdf(X_pinwheel, ddpm_samples, model_name='DDPM', dataset_name='Pinwheel')
# Out:
# No. of clean samples = 2000
# Mean log(pdf) for DDPM generated Pinwheel dataset = -1.2386500936002944

# %% [markdown]
# ### 2.3 Generative Adversarial Networks (GAN)

# %%
generator = GAN_generator(features=[256, 256, 2])
discriminator = GAN_discriminator(features=[256, 256, 1])

print(generator.tabulate(jax.random.PRNGKey(0), np.zeros((1, 2))))
print(discriminator.tabulate(jax.random.PRNGKey(0), np.zeros((1, 2))))
# Out:
#                              GAN_generator Summary
# ┏━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┓
# ┃ path    ┃ module        ┃ inputs         ┃ outputs        ┃ params           ┃
# ┡━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━┩
# │         │ GAN_generator │ float32[1,2]   │ float32[1,2]   │                  │
# ├─────────┼───────────────┼────────────────┼────────────────┼──────────────────┤
# │ Dense_0 │ Dense         │ float32[1,2]   │ float32[1,256] │ bias:            │
# │         │               │                │                │ float32[256]     │
# │         │               │                │                │ kernel:          │
# │         │               │                │                │ float32[2,256]   │
# │         │               │                │                │                  │
# │         │               │                │                │ 768 (3.1 KB)     │
# ├─────────┼───────────────┼────────────────┼────────────────┼──────────────────┤
# │ Dense_1 │ Dense         │ float32[1,256] │ float32[1,256] │ bias:            │
# │         │               │                │                │ float32[256]     │
# │         │               │                │                │ kernel:          │
# │         │               │                │                │ float32[256,256] │
# │         │               │                │                │                  │
# │         │               │                │                │ 65,792 (263.2    │
# │         │               │                │                │ KB)              │
# ├─────────┼───────────────┼────────────────┼────────────────┼──────────────────┤
# │ Dense_2 │ Dense         │ float32[1,256] │ float32[1,2]   │ bias: float32[2] │
# │         │               │                │                │ kernel:          │
# │         │               │                │                │ float32[256,2]   │
# │         │               │                │                │                  │
# │         │               │                │                │ 514 (2.1 KB)     │
# ├─────────┼───────────────┼────────────────┼────────────────┼──────────────────┤
# │         │               │                │          Total │ 67,074 (268.3    │
# │         │               │                │                │ KB)              │
# └─────────┴───────────────┴────────────────┴────────────────┴──────────────────┘
#
#                       Total Parameters: 67,074 (268.3 KB)
#
#
#
#                            GAN_discriminator Summary
# ┏━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┓
# ┃ path    ┃ module          ┃ inputs         ┃ outputs        ┃ params         ┃
# ┡━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━┩
# │         │ GAN_discrimina… │ float32[1,2]   │ float32[1,1]   │                │
# ├─────────┼─────────────────┼────────────────┼────────────────┼────────────────┤
# │ Dense_0 │ Dense           │ float32[1,2]   │ float32[1,256] │ bias:          │
# │         │                 │                │                │ float32[256]   │
# │         │                 │                │                │ kernel:        │
# │         │                 │                │                │ float32[2,256] │
# │         │                 │                │                │                │
# │         │                 │                │                │ 768 (3.1 KB)   │
# ├─────────┼─────────────────┼────────────────┼────────────────┼────────────────┤
# │ Dense_1 │ Dense           │ float32[1,256] │ float32[1,256] │ bias:          │
# │         │                 │                │                │ float32[256]   │
# │         │                 │                │                │ kernel:        │
# │         │                 │                │                │ float32[256,2… │
# │         │                 │                │                │                │
# │         │                 │                │                │ 65,792 (263.2  │
# │         │                 │                │                │ KB)            │
# ├─────────┼─────────────────┼────────────────┼────────────────┼────────────────┤
# │ Dense_2 │ Dense           │ float32[1,256] │ float32[1,1]   │ bias:          │
# │         │                 │                │                │ float32[1]     │
# │         │                 │                │                │ kernel:        │
# │         │                 │                │                │ float32[256,1] │
# │         │                 │                │                │                │
# │         │                 │                │                │ 257 (1.0 KB)   │
# ├─────────┼─────────────────┼────────────────┼────────────────┼────────────────┤
# │         │                 │                │          Total │ 66,817 (267.3  │
# │         │                 │                │                │ KB)            │
# └─────────┴─────────────────┴────────────────┴────────────────┴────────────────┘
#
#                       Total Parameters: 66,817 (267.3 KB)

# %%
## Training
gen_params, train_gen_losses, train_disc_losses, val_gen_losses, val_disc_losses = GAN_train(
    X_pinwheel, lr=1e-4, clip_norm=0.1, eps=1e-8, num_epochs=1000000, batch_size=64, key=prng_seq
)
# Out:
# 100%|██████████| 1000000/1000000 [4:57:16<00:00, 56.06it/s]

# %%
## Loss plots
GAN_training_plot(train_gen_losses, train_disc_losses, val_gen_losses, val_disc_losses, title='GAN: Pinwheel')

# %%
## Generation
gan_samples = GAN_sampler(gen_params, X_pinwheel, noise)

# %%
## Energy density plot
'''
Lower energy signifies concentration of probability where datapoints should be.
'''
# Define the range for the grid
grid_x = np.linspace(np.min(X_pinwheel[:, 0])-1, np.max(X_pinwheel[:, 0])+1, 100)
grid_y = np.linspace(np.min(X_pinwheel[:, 1])-1, np.max(X_pinwheel[:, 1])+1, 100)

gan_plot_energy_landscape(generator, gen_params, grid_x, grid_y)
# Out:
# (10000, 2)
# (100, 100)

# %%
## Gaussian KDE
plot_logpdf(X_pinwheel, gan_samples, model_name='GAN', dataset_name='Pinwheel')
# Out:
# No. of clean samples = 2000
# Mean log(pdf) for GAN generated Pinwheel dataset = -0.6129366111434248

# %% [markdown]
# ### 2.4 Energy Based Model (EBM)

# %%
# The last layer has a single output for energy
ebm_model = EBM_MLP(features=[64, 64, 1], out_activation=None)
step_size = 5e-3
num_steps = 1000

print(ebm_model.tabulate(jax.random.PRNGKey(0), np.zeros((1, 2))))
# Out:
#                                EBM_MLP Summary
# ┏━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ path    ┃ module  ┃ inputs        ┃ outputs       ┃ params                 ┃
# ┡━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         │ EBM_MLP │ float32[1,2]  │ float32[1,1]  │                        │
# ├─────────┼─────────┼───────────────┼───────────────┼────────────────────────┤
# │ Dense_0 │ Dense   │ float32[1,2]  │ float32[1,64] │ bias: float32[64]      │
# │         │         │               │               │ kernel: float32[2,64]  │
# │         │         │               │               │                        │
# │         │         │               │               │ 192 (768 B)            │
# ├─────────┼─────────┼───────────────┼───────────────┼────────────────────────┤
# │ Dense_1 │ Dense   │ float32[1,64] │ float32[1,64] │ bias: float32[64]      │
# │         │         │               │               │ kernel: float32[64,64] │
# │         │         │               │               │                        │
# │         │         │               │               │ 4,160 (16.6 KB)        │
# ├─────────┼─────────┼───────────────┼───────────────┼────────────────────────┤
# │ Dense_2 │ Dense   │ float32[1,64] │ float32[1,1]  │ bias: float32[1]       │
# │         │         │               │               │ kernel: float32[64,1]  │
# │         │         │               │               │                        │
# │         │         │               │               │ 65 (260 B)             │
# ├─────────┼─────────┼───────────────┼───────────────┼────────────────────────┤
# │         │         │               │         Total │ 4,417 (17.7 KB)        │
# └─────────┴─────────┴───────────────┴───────────────┴────────────────────────┘
#
#                       Total Parameters: 4,417 (17.7 KB)

# %%
## Training
params, train_losses, val_losses = EBM_train(X_pinwheel, lr=1e-3, clip_norm=0.1, 
                                     l2=0.1, num_epochs=2000, batch_size=128, key=prng_seq)
# Out:
# 100%|██████████| 2000/2000 [51:55<00:00,  1.56s/it]

# %%
## Loss plots
EBM_training_plot(train_losses, val_losses, title='EBM: Pinwheel')

# %%
## Generation
ebm_samples = EBM_sampler(params, X_pinwheel, noise, step_size, num_steps, key=prng_seq)

# %%
## Energy density plot
'''
Lower energy signifies concentration of probability where datapoints should be.
'''
# Define the range for the grid
grid_x = np.linspace(np.min(X_pinwheel[:, 0])-1, np.max(X_pinwheel[:, 0])+1, 100)
grid_y = np.linspace(np.min(X_pinwheel[:, 1])-1, np.max(X_pinwheel[:, 1])+1, 100)

ebm_plot_energy_landscape(ebm_model, params, grid_x, grid_y)

# %%
## Gaussian KDE
plot_logpdf(X_pinwheel, ebm_samples, model_name='EBM', dataset_name='Pinwheel')
# Out:
# No. of clean samples = 2000
# Mean log(pdf) for EBM generated Pinwheel dataset = -751.488363255706
